# %%
# !pip install pillow
# !pip install split-folders
# !pip install wandb -qqq
import splitfolders
import tensorflow as tf
import matplotlib.pyplot as plt
import wandb
from wandb.keras import WandbCallback

import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.optimizers import SGD
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
#      |████████████████████████████████| 2.1MB 9.7MB/s
#      |████████████████████████████████| 102kB 12.2MB/s
#      |████████████████████████████████| 133kB 50.6MB/s
#      |████████████████████████████████| 163kB 55.0MB/s
#      |████████████████████████████████| 71kB 11.0MB/s
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue May  4 10:31:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Parameters
batch_size = 160
size=(224, 224)
num_classes = 15
input_tensor = (224, 224, 3)
dropout_rate=0.2
epochs=15
lr=1e-1
TL=True
split=(0.8, 0.1, 0.1)
data_dir='/content/output/'

# %%
wandb.login()
run = wandb.init(project='Deep Learning Assignment',
                 config={  
                     "learning_rate": lr,
                     "epochs": epochs,
                     "batch_size": batch_size,
                     "loss_function": "categorical_crossentropy",
                     "architecture": "ResNet-50V2",
                     "dataset": "Plant Village",
                     "optimizer":"SGD",
                     "Split": split,
                     "Transfer Learning": TL,
                     "Data Aug": True
                 })
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: flashrender (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.29<br/>
#                 Syncing run <strong style="color:#cdcd00">rosy-paper-23</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment</a><br/>
#                 Run page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/1j1c3f7c" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/1j1c3f7c</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210504_103148-1j1c3f7c</code><br/><br/>

# %%
# !wget http://drive.genos-drive.workers.dev/plantvillage.zip
# !unzip -qq plantvillage.zip 
splitfolders.ratio('PlantVillage', output="output", ratio=split)
# Out:
# --2021-05-04 10:31:51--  http://drive.genos-drive.workers.dev/plantvillage.zip
# Resolving drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)... 104.21.234.166, 104.21.234.167, 2606:4700:3038::6815:eaa7, ...
# Connecting to drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)|104.21.234.166|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689512690 (658M) [application/zip]
# Saving to: ‘plantvillage.zip’
#
# plantvillage.zip    100%[===================>] 657.57M  32.6MB/s    in 24s
#
# 2021-05-04 10:32:16 (27.6 MB/s) - ‘plantvillage.zip’ saved [689512690/689512690]
# Copying files: 20639 files [00:02, 7387.60 files/s]

# %%
data_augmentation = keras.Sequential(
    [
        tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255.)
    ]
)
def load_dataset(dir, train):
  dataset = keras.preprocessing.image_dataset_from_directory(
        dir,  
        image_size=size, 
        batch_size=batch_size,
        labels="inferred",
        seed=1337,
        label_mode="categorical",
        color_mode="rgb",
        shuffle=True)
  dataset=dataset.map(lambda x, y: (data_augmentation(x, training=train), y))
  return dataset.prefetch(buffer_size=batch_size)

# %%
train_generator = load_dataset(data_dir+'train', True)
validation_generator = load_dataset(data_dir+'val', False)
test_generator = load_dataset(data_dir+'test', False)
# Out:
# Found 16504 files belonging to 15 classes.
# Found 2058 files belonging to 15 classes.
# Found 2076 files belonging to 15 classes.

# %%
img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
inputs = tf.keras.layers.Input(shape=input_tensor)
x = img_augmentation(inputs)

base_model = tf.keras.applications.ResNet50V2(input_tensor=x,include_top=False)
x = base_model.output
x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x)
predictions = keras.layers.Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)


model.compile(optimizer=SGD(lr=lr, momentum=0.9), loss='categorical_crossentropy',metrics=[tf.keras.metrics.CategoricalAccuracy()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5), 
    tf.keras.callbacks.ModelCheckpoint(filepath='modelcheckpoint/model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=0.0001),
    WandbCallback()
]

# %%
history=model.fit(train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=my_callbacks)
# Out:
# Epoch 1/15
#   6/104 [>.............................] - ETA: 1:01 - loss: 2.2633 - categorical_accuracy: 0.3376WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1943s vs `on_train_batch_end` time: 0.2791s). Check your callbacks.
# 104/104 [==============================] - 73s 468ms/step - loss: 0.8459 - categorical_accuracy: 0.7463 - val_loss: 9.4894 - val_categorical_accuracy: 0.1914
# Epoch 2/15
# 104/104 [==============================] - 46s 429ms/step - loss: 0.2481 - categorical_accuracy: 0.9174 - val_loss: 1.8375 - val_categorical_accuracy: 0.6540
# Epoch 3/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.1558 - categorical_accuracy: 0.9509 - val_loss: 3.2357 - val_categorical_accuracy: 0.5083
# Epoch 4/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.0319 - categorical_accuracy: 0.9891 - val_loss: 0.1597 - val_categorical_accuracy: 0.9514
# Epoch 5/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.0356 - categorical_accuracy: 0.9866 - val_loss: 0.6732 - val_categorical_accuracy: 0.8620
# Epoch 6/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.0602 - categorical_accuracy: 0.9808 - val_loss: 0.4422 - val_categorical_accuracy: 0.8892
# Epoch 7/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.0250 - categorical_accuracy: 0.9918 - val_loss: 0.1089 - val_categorical_accuracy: 0.9679
# Epoch 8/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.0092 - categorical_accuracy: 0.9969 - val_loss: 0.1724 - val_categorical_accuracy: 0.9577
# Epoch 9/15
# 104/104 [==============================] - 46s 428ms/step - loss: 0.0285 - categorical_accuracy: 0.9923 - val_loss: 0.1144 - val_categorical_accuracy: 0.9636
# Epoch 10/15
# 104/104 [==============================] - 46s 429ms/step - loss: 0.0108 - categorical_accuracy: 0.9961 - val_loss: 0.0662 - val_categorical_accuracy: 0.9806
# Epoch 11/15
# 104/104 [==============================] - 47s 429ms/step - loss: 0.0023 - categorical_accuracy: 0.9996 - val_loss: 0.0247 - val_categorical_accuracy: 0.9917
# Epoch 12/15
# 104/104 [==============================] - 46s 429ms/step - loss: 4.6122e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0481 - val_categorical_accuracy: 0.9835
# Epoch 13/15
# 104/104 [==============================] - 46s 429ms/step - loss: 6.1036e-04 - categorical_accuracy: 0.9997 - val_loss: 0.0399 - val_categorical_accuracy: 0.9854
# Epoch 14/15
# 104/104 [==============================] - 46s 429ms/step - loss: 0.0220 - categorical_accuracy: 0.9944 - val_loss: 0.3595 - val_categorical_accuracy: 0.9155
# Epoch 15/15
# 104/104 [==============================] - 46s 429ms/step - loss: 0.0016 - categorical_accuracy: 0.9996 - val_loss: 0.0535 - val_categorical_accuracy: 0.9830

# %%
print("Evaluate on test data")
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 13/13 [==============================] - 5s 259ms/step - loss: 0.0604 - categorical_accuracy: 0.9851
# test loss, test acc: [0.06035742163658142, 0.9850674271583557]

# %%
best_model="/content/modelcheckpoint/model.11-0.02.h5"
modeltest = keras.models.load_model(best_model)
wandb.save(best_model)
results = modeltest.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# 13/13 [==============================] - 5s 191ms/step - loss: 0.0494 - categorical_accuracy: 0.9855
# test loss, test acc: [0.04941040277481079, 0.9855491518974304]

# %%
# !zip -r my_model.zip modelcheckpoint/ wandb/ logs/
# !cp my_model.zip "/content/drive/Shareddrives/Untitled shared drive/my_model_EfficientNetB0.zip"

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
wandb.save(best_model)
# Out:
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# ['/content/wandb/run-20210504_103148-1j1c3f7c/files/model.11-0.02.h5',
#  '/content/wandb/run-20210504_103148-1j1c3f7c/files/model.11-0.02.h5']

# %%
# !pip install pillow
# !pip install split-folders
# !pip install wandb -qqq
import splitfolders
import tensorflow as tf
import matplotlib.pyplot as plt
import wandb
from wandb.keras import WandbCallback

import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.optimizers import SGD
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
#      |████████████████████████████████| 2.1MB 13.4MB/s
#      |████████████████████████████████| 133kB 56.4MB/s
#      |████████████████████████████████| 102kB 11.3MB/s
#      |████████████████████████████████| 163kB 36.1MB/s
#      |████████████████████████████████| 71kB 10.1MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue May  4 10:51:29 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Parameters
batch_size = 160
size=(224, 224)
num_classes = 15
input_tensor = (224, 224, 3)
dropout_rate=0.2
epochs=25
lr=5e-3
TL=True
split=(0.8, 0.1, 0.1)
data_dir='/content/output/'

# %%
wandb.login()
run = wandb.init(project='Deep Learning Assignment',
                 config={  
                     "learning_rate": lr,
                     "epochs": epochs,
                     "batch_size": batch_size,
                     "loss_function": "categorical_crossentropy",
                     "architecture": "ResNet-50V2",
                     "dataset": "Plant Village",
                     "optimizer":"SGD",
                     "Split": split,
                     "Transfer Learning": TL,
                     "Data Aug": True
                 })
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing last run (ID:13nckdvx) before initializing another...
# <br/>Waiting for W&B process to finish, PID 180<br/>Program ended successfully.
# VBox(children=(Label(value=' 361.38MB of 361.38MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=…
# Find user logs for this run at: <code>/content/wandb/run-20210504_105237-13nckdvx/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210504_105237-13nckdvx/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.00198</td></tr><tr><td>categorical_accuracy</td><td>0.99945</td></tr><tr><td>val_loss</td><td>0.02044</td></tr><tr><td>val_categorical_accuracy</td><td>0.99514</td></tr><tr><td>lr</td><td>0.009</td></tr><tr><td>_runtime</td><td>1334</td></tr><tr><td>_timestamp</td><td>1620126891</td></tr><tr><td>_step</td><td>24</td></tr><tr><td>best_val_loss</td><td>0.01466</td></tr><tr><td>best_epoch</td><td>21</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>categorical_accuracy</td><td>▁▅▇▇▇▇████▇██████████████</td></tr><tr><td>val_loss</td><td>█▂▃▂▁▁▂▁▁▂▂▃▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_categorical_accuracy</td><td>▁▆▅▇▇▇▇██▇▇▆█████████████</td></tr><tr><td>lr</td><td>████████████▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>_timestamp</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>_step</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 2 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">winter-moon-25</strong>: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/13nckdvx" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/13nckdvx</a><br/>
# ...Successfully finished last run (ID:13nckdvx). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.29<br/>
#                 Syncing run <strong style="color:#cdcd00">lilac-wave-27</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment</a><br/>
#                 Run page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/tmrzbdzh" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/tmrzbdzh</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210504_111700-tmrzbdzh</code><br/><br/>

# %%
# !wget http://drive.genos-drive.workers.dev/plantvillage.zip
# !unzip -qq plantvillage.zip 
splitfolders.ratio('PlantVillage', output="output", ratio=split)
# Out:
# --2021-05-04 10:52:39--  http://drive.genos-drive.workers.dev/plantvillage.zip
# Resolving drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)... 104.21.234.166, 104.21.234.167, 2606:4700:3038::6815:eaa7, ...
# Connecting to drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)|104.21.234.166|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689512690 (658M) [application/zip]
# Saving to: ‘plantvillage.zip’
#
# plantvillage.zip    100%[===================>] 657.57M  35.5MB/s    in 19s
#
# 2021-05-04 10:53:00 (34.9 MB/s) - ‘plantvillage.zip’ saved [689512690/689512690]
# Copying files: 20639 files [00:02, 6881.76 files/s]

# %%
data_augmentation = keras.Sequential(
    [
        tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255.)
    ]
)
def load_dataset(dir, train):
  dataset = keras.preprocessing.image_dataset_from_directory(
        dir,  
        image_size=size, 
        batch_size=batch_size,
        labels="inferred",
        seed=1337,
        label_mode="categorical",
        color_mode="rgb",
        shuffle=True)
  dataset=dataset.map(lambda x, y: (data_augmentation(x, training=train), y))
  return dataset.prefetch(buffer_size=batch_size)

# %%
train_generator = load_dataset(data_dir+'train', True)
validation_generator = load_dataset(data_dir+'val', False)
test_generator = load_dataset(data_dir+'test', False)
# Out:
# Found 16504 files belonging to 15 classes.
# Found 2058 files belonging to 15 classes.
# Found 2076 files belonging to 15 classes.

# %%
img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
inputs = tf.keras.layers.Input(shape=input_tensor)
x = img_augmentation(inputs)

base_model = tf.keras.applications.ResNet50V2(input_tensor=x,include_top=False)
x = base_model.output
x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x)
predictions = keras.layers.Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)


model.compile(optimizer=SGD(lr=lr, momentum=0.9), loss='categorical_crossentropy',metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5), 
    tf.keras.callbacks.ModelCheckpoint(filepath='modelcheckpoint/model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=0.0001),
    WandbCallback()
]

# %%
history=model.fit(train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=my_callbacks)
# Out:
# Epoch 1/25
#   6/104 [>.............................] - ETA: 1:17 - loss: 2.9737 - categorical_accuracy: 0.0692WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2043s vs `on_train_batch_end` time: 0.4431s). Check your callbacks.
# 104/104 [==============================] - 57s 484ms/step - loss: 1.2866 - categorical_accuracy: 0.5976 - val_loss: 1.0977 - val_categorical_accuracy: 0.7352
# Epoch 2/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.1511 - categorical_accuracy: 0.9519 - val_loss: 0.4473 - val_categorical_accuracy: 0.8654
# Epoch 3/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0699 - categorical_accuracy: 0.9779 - val_loss: 0.2701 - val_categorical_accuracy: 0.9062
# Epoch 4/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0495 - categorical_accuracy: 0.9827 - val_loss: 0.1191 - val_categorical_accuracy: 0.9650
# Epoch 5/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0382 - categorical_accuracy: 0.9882 - val_loss: 0.0695 - val_categorical_accuracy: 0.9728
# Epoch 6/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0304 - categorical_accuracy: 0.9898 - val_loss: 0.0865 - val_categorical_accuracy: 0.9723
# Epoch 7/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0246 - categorical_accuracy: 0.9920 - val_loss: 0.1881 - val_categorical_accuracy: 0.9378
# Epoch 8/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0203 - categorical_accuracy: 0.9935 - val_loss: 0.1810 - val_categorical_accuracy: 0.9422
# Epoch 9/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0240 - categorical_accuracy: 0.9912 - val_loss: 0.0348 - val_categorical_accuracy: 0.9874
# Epoch 10/25
# 104/104 [==============================] - 49s 455ms/step - loss: 0.0121 - categorical_accuracy: 0.9964 - val_loss: 0.0442 - val_categorical_accuracy: 0.9845
# Epoch 11/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0089 - categorical_accuracy: 0.9980 - val_loss: 0.0329 - val_categorical_accuracy: 0.9869
# Epoch 12/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0092 - categorical_accuracy: 0.9978 - val_loss: 0.0304 - val_categorical_accuracy: 0.9898
# Epoch 13/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0077 - categorical_accuracy: 0.9981 - val_loss: 0.0347 - val_categorical_accuracy: 0.9879
# Epoch 14/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0090 - categorical_accuracy: 0.9973 - val_loss: 0.0380 - val_categorical_accuracy: 0.9869
# Epoch 15/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0092 - categorical_accuracy: 0.9969 - val_loss: 0.0453 - val_categorical_accuracy: 0.9854
# Epoch 16/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0067 - categorical_accuracy: 0.9983 - val_loss: 0.0381 - val_categorical_accuracy: 0.9883
# Epoch 17/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0075 - categorical_accuracy: 0.9978 - val_loss: 0.0256 - val_categorical_accuracy: 0.9903
# Epoch 18/25
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0070 - categorical_accuracy: 0.9984 - val_loss: 0.0247 - val_categorical_accuracy: 0.9917
# Epoch 19/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0059 - categorical_accuracy: 0.9989 - val_loss: 0.0281 - val_categorical_accuracy: 0.9893
# Epoch 20/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0062 - categorical_accuracy: 0.9983 - val_loss: 0.0262 - val_categorical_accuracy: 0.9927
# Epoch 21/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0061 - categorical_accuracy: 0.9982 - val_loss: 0.0255 - val_categorical_accuracy: 0.9903
# Epoch 22/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0060 - categorical_accuracy: 0.9982 - val_loss: 0.0264 - val_categorical_accuracy: 0.9903
# Epoch 23/25
# 104/104 [==============================] - 49s 456ms/step - loss: 0.0073 - categorical_accuracy: 0.9984 - val_loss: 0.0262 - val_categorical_accuracy: 0.9922

# %%
print("Evaluate on test data")
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 13/13 [==============================] - 4s 179ms/step - loss: 0.0374 - categorical_accuracy: 0.9880
# test loss, test acc: [0.03737602382898331, 0.9879575967788696]

# %%
best_model="/content/modelcheckpoint/model.23-0.03.h5"
modeltest = keras.models.load_model(best_model)
wandb.save(best_model)
results = modeltest.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# 13/13 [==============================] - 5s 183ms/step - loss: 0.0374 - categorical_accuracy: 0.9880
# test loss, test acc: [0.03737602382898331, 0.9879575967788696]

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !pip install pillow
# !pip install split-folders
# !pip install wandb -qqq
import splitfolders
import tensorflow as tf
import matplotlib.pyplot as plt
import wandb
from wandb.keras import WandbCallback

import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.optimizers import SGD
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
#      |████████████████████████████████| 2.1MB 11.9MB/s
#      |████████████████████████████████| 163kB 45.2MB/s
#      |████████████████████████████████| 133kB 46.6MB/s
#      |████████████████████████████████| 102kB 10.3MB/s
#      |████████████████████████████████| 71kB 7.8MB/s
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue May  4 10:58:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Parameters
batch_size = 160
size=(224, 224)
num_classes = 15
input_tensor = (224, 224, 3)
dropout_rate=0.2
epochs=30
lr=1e-3
TL=True
split=(0.8, 0.1, 0.1)
data_dir='/content/output/'

# %%
wandb.login()
run = wandb.init(project='Deep Learning Assignment',
                 config={  
                     "learning_rate": lr,
                     "epochs": epochs,
                     "batch_size": batch_size,
                     "loss_function": "categorical_crossentropy",
                     "architecture": "ResNet-50V2",
                     "dataset": "Plant Village",
                     "optimizer":"SGD",
                     "Split": split,
                     "Transfer Learning": TL,
                     "Data Aug": True
                 })
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: flashrender (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.29<br/>
#                 Syncing run <strong style="color:#cdcd00">polar-donkey-26</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment</a><br/>
#                 Run page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/3fk6fqor" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/3fk6fqor</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210504_105922-3fk6fqor</code><br/><br/>

# %%
# !wget http://drive.genos-drive.workers.dev/plantvillage.zip
# !unzip -qq plantvillage.zip 
splitfolders.ratio('PlantVillage', output="output", ratio=split)
# Out:
# --2021-05-04 10:59:25--  http://drive.genos-drive.workers.dev/plantvillage.zip
# Resolving drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)... 104.21.234.167, 104.21.234.166, 2606:4700:3038::6815:eaa6, ...
# Connecting to drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)|104.21.234.167|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689512690 (658M) [application/zip]
# Saving to: ‘plantvillage.zip’
#
# plantvillage.zip    100%[===================>] 657.57M  38.0MB/s    in 17s
#
# 2021-05-04 10:59:44 (38.0 MB/s) - ‘plantvillage.zip’ saved [689512690/689512690]
# Copying files: 20639 files [00:03, 5353.33 files/s]

# %%
data_augmentation = keras.Sequential(
    [
        tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255.)
    ]
)
def load_dataset(dir, train):
  dataset = keras.preprocessing.image_dataset_from_directory(
        dir,  
        image_size=size, 
        batch_size=batch_size,
        labels="inferred",
        seed=1337,
        label_mode="categorical",
        color_mode="rgb",
        shuffle=True)
  dataset=dataset.map(lambda x, y: (data_augmentation(x, training=train), y))
  return dataset.prefetch(buffer_size=batch_size)

# %%
train_generator = load_dataset(data_dir+'train', True)
validation_generator = load_dataset(data_dir+'val', False)
test_generator = load_dataset(data_dir+'test', False)
# Out:
# Found 16504 files belonging to 15 classes.
# Found 2058 files belonging to 15 classes.
# Found 2076 files belonging to 15 classes.

# %%
img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
inputs = tf.keras.layers.Input(shape=input_tensor)
x = img_augmentation(inputs)

base_model = tf.keras.applications.ResNet50V2(input_tensor=x,include_top=False)
x = base_model.output
x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x)
predictions = keras.layers.Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)


model.compile(optimizer=SGD(lr=lr, momentum=0.9), loss='categorical_crossentropy',metrics=[tf.keras.metrics.CategoricalAccuracy()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 2s 0us/step

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5), 
    tf.keras.callbacks.ModelCheckpoint(filepath='modelcheckpoint/model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=0.0001),
    WandbCallback()
]

# %%
history=model.fit(train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=my_callbacks)
# Out:
# Epoch 1/30
#   6/104 [>.............................] - ETA: 1:32 - loss: 3.0480 - categorical_accuracy: 0.0592WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2928s vs `on_train_batch_end` time: 0.4807s). Check your callbacks.
# 104/104 [==============================] - 107s 785ms/step - loss: 1.9805 - categorical_accuracy: 0.3929 - val_loss: 1.5876 - val_categorical_accuracy: 0.5413
# Epoch 2/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.4379 - categorical_accuracy: 0.8652 - val_loss: 0.6208 - val_categorical_accuracy: 0.7877
# Epoch 3/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.2361 - categorical_accuracy: 0.9259 - val_loss: 0.3425 - val_categorical_accuracy: 0.8868
# Epoch 4/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.1632 - categorical_accuracy: 0.9497 - val_loss: 0.1890 - val_categorical_accuracy: 0.9373
# Epoch 5/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.1215 - categorical_accuracy: 0.9618 - val_loss: 0.1432 - val_categorical_accuracy: 0.9475
# Epoch 6/30
# 104/104 [==============================] - 79s 742ms/step - loss: 0.0962 - categorical_accuracy: 0.9695 - val_loss: 0.1488 - val_categorical_accuracy: 0.9466
# Epoch 7/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0801 - categorical_accuracy: 0.9755 - val_loss: 0.1378 - val_categorical_accuracy: 0.9538
# Epoch 8/30
# 104/104 [==============================] - 79s 742ms/step - loss: 0.0675 - categorical_accuracy: 0.9793 - val_loss: 0.1249 - val_categorical_accuracy: 0.9587
# Epoch 9/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0594 - categorical_accuracy: 0.9822 - val_loss: 0.1334 - val_categorical_accuracy: 0.9548
# Epoch 10/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0493 - categorical_accuracy: 0.9858 - val_loss: 0.1362 - val_categorical_accuracy: 0.9538
# Epoch 11/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0431 - categorical_accuracy: 0.9863 - val_loss: 0.1135 - val_categorical_accuracy: 0.9606
# Epoch 12/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0416 - categorical_accuracy: 0.9879 - val_loss: 0.0749 - val_categorical_accuracy: 0.9776
# Epoch 13/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0330 - categorical_accuracy: 0.9908 - val_loss: 0.0685 - val_categorical_accuracy: 0.9772
# Epoch 14/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0348 - categorical_accuracy: 0.9883 - val_loss: 0.0741 - val_categorical_accuracy: 0.9733
# Epoch 15/30
# 104/104 [==============================] - 79s 744ms/step - loss: 0.0324 - categorical_accuracy: 0.9889 - val_loss: 0.1103 - val_categorical_accuracy: 0.9611
# Epoch 16/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0358 - categorical_accuracy: 0.9892 - val_loss: 0.0758 - val_categorical_accuracy: 0.9752
# Epoch 17/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0242 - categorical_accuracy: 0.9929 - val_loss: 0.0600 - val_categorical_accuracy: 0.9791
# Epoch 18/30
# 104/104 [==============================] - 80s 743ms/step - loss: 0.0228 - categorical_accuracy: 0.9941 - val_loss: 0.0611 - val_categorical_accuracy: 0.9796
# Epoch 19/30
# 104/104 [==============================] - 80s 745ms/step - loss: 0.0201 - categorical_accuracy: 0.9951 - val_loss: 0.0551 - val_categorical_accuracy: 0.9830
# Epoch 20/30
# 104/104 [==============================] - 80s 743ms/step - loss: 0.0202 - categorical_accuracy: 0.9945 - val_loss: 0.0555 - val_categorical_accuracy: 0.9806
# Epoch 21/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0186 - categorical_accuracy: 0.9946 - val_loss: 0.0564 - val_categorical_accuracy: 0.9810
# Epoch 22/30
# 104/104 [==============================] - 80s 744ms/step - loss: 0.0195 - categorical_accuracy: 0.9945 - val_loss: 0.0558 - val_categorical_accuracy: 0.9815
# Epoch 23/30
# 104/104 [==============================] - 80s 744ms/step - loss: 0.0188 - categorical_accuracy: 0.9947 - val_loss: 0.0554 - val_categorical_accuracy: 0.9815
# Epoch 24/30
# 104/104 [==============================] - 79s 744ms/step - loss: 0.0191 - categorical_accuracy: 0.9953 - val_loss: 0.0543 - val_categorical_accuracy: 0.9825
# Epoch 25/30
# 104/104 [==============================] - 80s 744ms/step - loss: 0.0185 - categorical_accuracy: 0.9949 - val_loss: 0.0553 - val_categorical_accuracy: 0.9835
# Epoch 26/30
# 104/104 [==============================] - 79s 744ms/step - loss: 0.0196 - categorical_accuracy: 0.9938 - val_loss: 0.0549 - val_categorical_accuracy: 0.9806
# Epoch 27/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0178 - categorical_accuracy: 0.9952 - val_loss: 0.0551 - val_categorical_accuracy: 0.9806
# Epoch 28/30
# 104/104 [==============================] - 79s 744ms/step - loss: 0.0193 - categorical_accuracy: 0.9951 - val_loss: 0.0533 - val_categorical_accuracy: 0.9815
# Epoch 29/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0161 - categorical_accuracy: 0.9960 - val_loss: 0.0559 - val_categorical_accuracy: 0.9815
# Epoch 30/30
# 104/104 [==============================] - 79s 743ms/step - loss: 0.0180 - categorical_accuracy: 0.9949 - val_loss: 0.0558 - val_categorical_accuracy: 0.9806

# %%
print("Evaluate on test data")
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 13/13 [==============================] - 8s 348ms/step - loss: 0.0493 - categorical_accuracy: 0.9836
# test loss, test acc: [0.049347639083862305, 0.9836223721504211]

# %%
best_model="/content/modelcheckpoint/model.25-0.06.h5"
modeltest = keras.models.load_model(best_model)
wandb.save(best_model)
results = modeltest.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# 13/13 [==============================] - 7s 257ms/step - loss: 0.0486 - categorical_accuracy: 0.9841
# test loss, test acc: [0.048611924052238464, 0.9841040372848511]

# %%
# !zip -r my_model.zip modelcheckpoint/ wandb/ logs/
# !cp my_model.zip "/content/drive/Shareddrives/Untitled shared drive/my_model_EfficientNetB0.zip"

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

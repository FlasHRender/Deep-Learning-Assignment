# %%
# !pip install pillow
# !pip install split-folders
# !pip install wandb -qqq
import splitfolders
import tensorflow as tf
import matplotlib.pyplot as plt
import wandb
from wandb.keras import WandbCallback

import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.optimizers import SGD
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
#      |████████████████████████████████| 2.1MB 12.2MB/s
#      |████████████████████████████████| 163kB 51.4MB/s
#      |████████████████████████████████| 133kB 54.3MB/s
#      |████████████████████████████████| 102kB 12.5MB/s
#      |████████████████████████████████| 71kB 10.5MB/s
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue May  4 09:43:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Parameters
batch_size = 160
size=(224, 224)
num_classes = 15
input_tensor = (224, 224, 3)
dropout_rate=0.2
epochs=80
lr=1e-2
TL=False
split=(0.8, 0.1, 0.1)
data_dir='/content/output/'

# %%
wandb.login()
run = wandb.init(project='Deep Learning Assignment',
                 config={  
                     "learning_rate": lr,
                     "epochs": epochs,
                     "batch_size": batch_size,
                     "loss_function": "categorical_crossentropy",
                     "architecture": "ResNet-50V2",
                     "dataset": "Plant Village",
                     "optimizer":"SGD",
                     "Split": split,
                     "Transfer Learning": TL,
                     "Data Aug": True
                 })
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: flashrender (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.29<br/>
#                 Syncing run <strong style="color:#cdcd00">crimson-bird-22</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment</a><br/>
#                 Run page: <a href="https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/f5lt5koc" target="_blank">https://wandb.ai/flashrender/Deep%20Learning%20Assignment/runs/f5lt5koc</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210504_094348-f5lt5koc</code><br/><br/>

# %%
# !wget http://drive.genos-drive.workers.dev/plantvillage.zip
# !unzip -qq plantvillage.zip 
splitfolders.ratio('PlantVillage', output="output", ratio=split)
# Out:
# --2021-05-04 09:43:59--  http://drive.genos-drive.workers.dev/plantvillage.zip
# Resolving drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)... 104.21.234.167, 104.21.234.166, 2606:4700:3038::6815:eaa7, ...
# Connecting to drive.genos-drive.workers.dev (drive.genos-drive.workers.dev)|104.21.234.167|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689512690 (658M) [application/zip]
# Saving to: ‘plantvillage.zip’
#
# plantvillage.zip    100%[===================>] 657.57M  64.7MB/s    in 20s
#
# 2021-05-04 09:44:21 (32.7 MB/s) - ‘plantvillage.zip’ saved [689512690/689512690]
# Copying files: 20639 files [00:02, 7126.35 files/s]

# %%
data_augmentation = keras.Sequential(
    [
        tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255.)
    ]
)
def load_dataset(dir, train):
  dataset = keras.preprocessing.image_dataset_from_directory(
        dir,  
        image_size=size, 
        batch_size=batch_size,
        labels="inferred",
        seed=1337,
        label_mode="categorical",
        color_mode="rgb",
        shuffle=True)
  dataset=dataset.map(lambda x, y: (data_augmentation(x, training=train), y))
  return dataset.prefetch(buffer_size=batch_size)

# %%
train_generator = load_dataset(data_dir+'train', True)
validation_generator = load_dataset(data_dir+'val', False)
test_generator = load_dataset(data_dir+'test', False)
# Out:
# Found 16504 files belonging to 15 classes.
# Found 2058 files belonging to 15 classes.
# Found 2076 files belonging to 15 classes.

# %%
img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
inputs = tf.keras.layers.Input(shape=input_tensor)
x = img_augmentation(inputs)

base_model = tf.keras.applications.ResNet50V2(input_tensor=x,include_top=False,weights=None)
x = base_model.output
x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x)
predictions = keras.layers.Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)


model.compile(optimizer=SGD(lr=lr, momentum=0.9), loss='categorical_crossentropy',metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5), 
    tf.keras.callbacks.ModelCheckpoint(filepath='modelcheckpoint/model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=0.0001),
    WandbCallback()
]

# %%
history=model.fit(train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=my_callbacks)
# Out:
# Epoch 1/80
#   6/104 [>.............................] - ETA: 1:05 - loss: 2.7719 - categorical_accuracy: 0.1090WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2056s vs `on_train_batch_end` time: 0.3060s). Check your callbacks.
# 104/104 [==============================] - 77s 496ms/step - loss: 2.0111 - categorical_accuracy: 0.3592 - val_loss: 3.2238 - val_categorical_accuracy: 0.1774
# Epoch 2/80
# 104/104 [==============================] - 49s 456ms/step - loss: 0.7643 - categorical_accuracy: 0.7444 - val_loss: 4.0364 - val_categorical_accuracy: 0.1769
# Epoch 3/80
# 104/104 [==============================] - 49s 456ms/step - loss: 0.4758 - categorical_accuracy: 0.8399 - val_loss: 2.7240 - val_categorical_accuracy: 0.3955
# Epoch 4/80
# 104/104 [==============================] - 49s 456ms/step - loss: 0.3491 - categorical_accuracy: 0.8823 - val_loss: 2.8431 - val_categorical_accuracy: 0.4359
# Epoch 5/80
# 104/104 [==============================] - 49s 456ms/step - loss: 0.2711 - categorical_accuracy: 0.9089 - val_loss: 4.6394 - val_categorical_accuracy: 0.3139
# Epoch 6/80
# 104/104 [==============================] - 49s 458ms/step - loss: 0.2307 - categorical_accuracy: 0.9205 - val_loss: 1.4802 - val_categorical_accuracy: 0.6074
# Epoch 7/80
# 104/104 [==============================] - 50s 457ms/step - loss: 0.2089 - categorical_accuracy: 0.9312 - val_loss: 0.3192 - val_categorical_accuracy: 0.9018
# Epoch 8/80
# 104/104 [==============================] - 50s 457ms/step - loss: 0.1571 - categorical_accuracy: 0.9439 - val_loss: 2.1715 - val_categorical_accuracy: 0.5311
# Epoch 9/80
# 104/104 [==============================] - 49s 457ms/step - loss: 0.1363 - categorical_accuracy: 0.9537 - val_loss: 0.4638 - val_categorical_accuracy: 0.8542
# Epoch 10/80
# 104/104 [==============================] - 49s 457ms/step - loss: 0.1489 - categorical_accuracy: 0.9475 - val_loss: 1.6287 - val_categorical_accuracy: 0.6273
# Epoch 11/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.1538 - categorical_accuracy: 0.9472 - val_loss: 0.6824 - val_categorical_accuracy: 0.8197
# Epoch 12/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0584 - categorical_accuracy: 0.9816 - val_loss: 0.1522 - val_categorical_accuracy: 0.9480
# Epoch 13/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0587 - categorical_accuracy: 0.9825 - val_loss: 0.1849 - val_categorical_accuracy: 0.9393
# Epoch 14/80
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0562 - categorical_accuracy: 0.9816 - val_loss: 0.0939 - val_categorical_accuracy: 0.9670
# Epoch 15/80
# 104/104 [==============================] - 50s 457ms/step - loss: 0.0447 - categorical_accuracy: 0.9871 - val_loss: 0.1306 - val_categorical_accuracy: 0.9587
# Epoch 16/80
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0520 - categorical_accuracy: 0.9834 - val_loss: 0.3437 - val_categorical_accuracy: 0.8907
# Epoch 17/80
# 104/104 [==============================] - 50s 457ms/step - loss: 0.0454 - categorical_accuracy: 0.9861 - val_loss: 0.1690 - val_categorical_accuracy: 0.9461
# Epoch 18/80
# 104/104 [==============================] - 50s 459ms/step - loss: 0.0425 - categorical_accuracy: 0.9867 - val_loss: 0.0786 - val_categorical_accuracy: 0.9742
# Epoch 19/80
# 104/104 [==============================] - 50s 459ms/step - loss: 0.0305 - categorical_accuracy: 0.9919 - val_loss: 0.0880 - val_categorical_accuracy: 0.9723
# Epoch 20/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0319 - categorical_accuracy: 0.9909 - val_loss: 0.1042 - val_categorical_accuracy: 0.9689
# Epoch 21/80
# 104/104 [==============================] - 50s 459ms/step - loss: 0.0327 - categorical_accuracy: 0.9894 - val_loss: 0.0768 - val_categorical_accuracy: 0.9738
# Epoch 22/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0284 - categorical_accuracy: 0.9919 - val_loss: 0.0618 - val_categorical_accuracy: 0.9781
# Epoch 23/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0313 - categorical_accuracy: 0.9908 - val_loss: 0.0684 - val_categorical_accuracy: 0.9762
# Epoch 24/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0300 - categorical_accuracy: 0.9914 - val_loss: 0.1005 - val_categorical_accuracy: 0.9645
# Epoch 25/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0280 - categorical_accuracy: 0.9925 - val_loss: 0.1029 - val_categorical_accuracy: 0.9621
# Epoch 26/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0296 - categorical_accuracy: 0.9921 - val_loss: 0.0601 - val_categorical_accuracy: 0.9796
# Epoch 27/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0301 - categorical_accuracy: 0.9910 - val_loss: 0.0623 - val_categorical_accuracy: 0.9776
# Epoch 28/80
# 104/104 [==============================] - 50s 459ms/step - loss: 0.0264 - categorical_accuracy: 0.9925 - val_loss: 0.0622 - val_categorical_accuracy: 0.9791
# Epoch 29/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0278 - categorical_accuracy: 0.9918 - val_loss: 0.0630 - val_categorical_accuracy: 0.9772
# Epoch 30/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0268 - categorical_accuracy: 0.9926 - val_loss: 0.0625 - val_categorical_accuracy: 0.9772
# Epoch 31/80
# 104/104 [==============================] - 50s 459ms/step - loss: 0.0262 - categorical_accuracy: 0.9936 - val_loss: 0.0541 - val_categorical_accuracy: 0.9781
# Epoch 32/80
# 104/104 [==============================] - 50s 459ms/step - loss: 0.0265 - categorical_accuracy: 0.9924 - val_loss: 0.0566 - val_categorical_accuracy: 0.9776
# Epoch 33/80
# 104/104 [==============================] - 49s 457ms/step - loss: 0.0264 - categorical_accuracy: 0.9930 - val_loss: 0.0580 - val_categorical_accuracy: 0.9762
# Epoch 34/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0250 - categorical_accuracy: 0.9927 - val_loss: 0.0615 - val_categorical_accuracy: 0.9767
# Epoch 35/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0250 - categorical_accuracy: 0.9937 - val_loss: 0.0544 - val_categorical_accuracy: 0.9791
# Epoch 36/80
# 104/104 [==============================] - 50s 458ms/step - loss: 0.0248 - categorical_accuracy: 0.9925 - val_loss: 0.0551 - val_categorical_accuracy: 0.9776

# %%
print("Evaluate on test data")
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 13/13 [==============================] - 7s 275ms/step - loss: 0.0673 - categorical_accuracy: 0.9812
# test loss, test acc: [0.0672728568315506, 0.9812138676643372]

# %%
modeltest = keras.models.load_model('/content/modelcheckpoint/model.35-0.05.h5')
wandb.save("/content/modelcheckpoint/model.35-0.05.h5")
results = modeltest.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# 13/13 [==============================] - 5s 188ms/step - loss: 0.0658 - categorical_accuracy: 0.9812
# test loss, test acc: [0.06583268940448761, 0.9812138676643372]

# %%
# !zip -r my_model.zip modelcheckpoint/ wandb/ logs/
# !cp my_model.zip "/content/drive/Shareddrives/Untitled shared drive/my_model_EfficientNetB0.zip"

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
